# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/12000-data-science-jobs-in-the-india/naukri_data_science_jobs_india.csv', index_col = ['Job_Role'])

df.head()

df.sort_index(inplace = True, ascending = False)

# %%
df
# Out:
#                                                                                         Company  \
# Job_Role
# urgent requirement For data scientist               Orcapod Consulting Services Private Limited
# urgent hiring For data engineers - bang / any                        Experis IT Private Limited
# senior python developer                                                  Talent Zone Consultant
# senior bigdata engineer or data architect                   Rectras Business Solutions Pvt Ltd.
# senior Data Analyst                                                        Spectral Consultants
# ...                                                                                         ...
# A fabulous opportunity For AWS Data Engineer(L3...                              Wissen Infotech
# A Data Scientists                                                       CareerXperts Consulting
# 15-20 days notice only | Senior Data Engineer |...                    Cians Analytics Pvt. Ltd.
# ...

# %%
df.iloc[0]
# Out:
# Company                     Orcapod Consulting Services Private Limited
# Location                                         Hyderabad/Secunderabad
# Job Experience                                                      4-6
# Skills/Description    git, written communication, unit testing, obje...
# Name: urgent requirement For data scientist, dtype: object

# %%
df.iloc[[0,10,100,1000]]
# Out:
#                                                                            Company  \
# Job_Role
# urgent requirement For data scientist  Orcapod Consulting Services Private Limited
# lead software engineer                                                Smart4talent
# Value Optimization Analyst                                    Corning Technologies
# Sr . Product Designer                                                      jupiter
#
#                                                      Location Job Experience  \
# Job_Role
# urgent requirement For data scientist  Hyderabad/Secunderabad            4-6
# lead software engineer                     Hyderabad, Gurgaon            7-9
# Value Optimization Analyst                   Gurgaon/Gurugram            3-5
# Sr . Product Designer                     Bangalore/Bengaluru            3-7
#
#                                                                       Skills/Description
# Job_Role
# ...

# %%
df.iloc[10:20]
# Out:
#                                                           Company  \
# Job_Role
# lead software engineer                               Smart4talent
# job opening For data engineers -Noida  Experis IT Private Limited
# iOS Sr . Developer                               Xemplar Insights
# engineer sdg                            DATA PATTERNS (I) PVT LTD
# data scientist - biotechnology Jobs         Right Step Consulting
# data scientist                                 Global Talent Pool
# data scientist                         Ankit Bhatnagar Consultant
# data science(R)                               FUTURES AND CAREERS
# data science analyst                                         CRED
# data engineers                                  Disha Consultants
#
#                                                        Location  \
# Job_Role
# lead software engineer                       Hyderabad, Gurgaon
# job opening For data engineers -Noida  Bangalore/Bengaluru, any
# ...
